# %% [markdown]
# # 07 - Merge caches, train, evaluate and export
# Attach the code bundle, stage 01 Output, and every completed cache notebook Output. Raw videos and stage 00 Output are not required. The stage verifies the deployment pose checkpoint against the cache SHA.

# %%
# %pip install -q --progress-bar off --disable-pip-version-check "ultralytics>=8.3,<9" "lap>=0.5.12" "scikit-learn>=1.4" "PyYAML>=6" "onnx>=1.15" "onnxscript>=0.1" "openvino>=2025.0"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import importlib.util
from pathlib import Path

candidates = sorted(Path('/kaggle/input').rglob('kaggle_staged.py'))
assert len(candidates) == 1, f'Attach exactly one code Dataset; found: {candidates}'
spec = importlib.util.spec_from_file_location('kaggle_staged', candidates[0])
ks = importlib.util.module_from_spec(spec)
spec.loader.exec_module(ks)

# %%
checkpoint = ks.stage07_train_temporal(
    sequence_length=32, window_stride=8, max_windows_per_family_split=10_000,
    hidden_dim=96, batch_size=128, epochs=30, learning_rate=1e-3,
    workers=0, seed=42,
)
print('Final classifier:', checkpoint)
# Out:
# Windowing sources: 100/5277
# Windowing sources: 200/5277
# Windowing sources: 300/5277
# Windowing sources: 400/5277
# Windowing sources: 500/5277
# Windowing sources: 600/5277
# Windowing sources: 700/5277
# Windowing sources: 800/5277
# Windowing sources: 900/5277
# Windowing sources: 1000/5277
# Windowing sources: 1100/5277
# Windowing sources: 1200/5277
# Windowing sources: 1300/5277
# Windowing sources: 1400/5277
# Windowing sources: 1500/5277
# Windowing sources: 1600/5277
# Windowing sources: 1700/5277
# Windowing sources: 1800/5277
# Windowing sources: 1900/5277
# Windowing sources: 2000/5277
# Windowing sources: 2100/5277
# Windowing sources: 2200/5277
# Windowing sources: 2300/5277
# Windowing sources: 2400/5277
# Windowing sources: 2500/5277
# Windowing sources: 2600/5277
# Windowing sources: 2700/5277
# Windowing sources: 2800/5277
# Windowing sources: 2900/5277
# Windowing sources: 3000/5277
# Windowing sources: 3100/5277
# Windowing sources: 3200/5277
# Windowing sources: 3300/5277
# Windowing sources: 3400/5277
# Windowing sources: 3500/5277
# Windowing sources: 3600/5277
# Windowing sources: 3700/5277
# Windowing sources: 3800/5277
# Windowing sources: 3900/5277
# Windowing sources: 4000/5277
# Windowing sources: 4100/5277
# Windowing sources: 4200/5277
# Windowing sources: 4300/5277
# Windowing sources: 4400/5277
# Windowing sources: 4500/5277
# Windowing sources: 4600/5277
# Windowing sources: 4700/5277
# Windowing sources: 4800/5277
# Windowing sources: 4900/5277
# Windowing sources: 5000/5277
# Windowing sources: 5100/5277
# Windowing sources: 5200/5277
# Windowing sources: 5277/5277
# split       dataset     label
# test        CAUCAFall   0           45
#                         1            3
#             FallVision  0          354
#                         1           90
#             MCFD        0          246
#                         1           34
#             UCF101      0         2145
#             URFD        0           38
#                         1            1
# train       CAUCAFall   0          382
#                         1          198
#             FallVision  0         3114
#                         1          656
#             MCFD        0          302
#                         1          351
#             UCF101      0        10000
#             URFD        0          195
#                         1           42
# validation  CAUCAFall   0           52
#                         1           29
#             FallVision  0          411
#                         1           84
#             MCFD        1           74
#             UCF101      0         1293
#             URFD        0           28
#                         1            4
# dtype: int64
# epoch=001 loss=0.4316 val_ap=0.7489 val_f1@0.5=0.6304
# epoch=002 loss=0.3029 val_ap=0.8283 val_f1@0.5=0.7541
# epoch=003 loss=0.2397 val_ap=0.8890 val_f1@0.5=0.7972
# epoch=004 loss=0.2029 val_ap=0.8885 val_f1@0.5=0.7953
# epoch=005 loss=0.1811 val_ap=0.9127 val_f1@0.5=0.8579
# epoch=006 loss=0.1737 val_ap=0.9224 val_f1@0.5=0.8213
# epoch=007 loss=0.1607 val_ap=0.9114 val_f1@0.5=0.8182
# epoch=008 loss=0.1527 val_ap=0.9148 val_f1@0.5=0.8229
# epoch=009 loss=0.1523 val_ap=0.9167 val_f1@0.5=0.8501
# epoch=010 loss=0.1470 val_ap=0.9426 val_f1@0.5=0.8517
# epoch=011 loss=0.1417 val_ap=0.9462 val_f1@0.5=0.8629
# epoch=012 loss=0.1376 val_ap=0.9476 val_f1@0.5=0.8728
# epoch=013 loss=0.1378 val_ap=0.9621 val_f1@0.5=0.8812
# epoch=014 loss=0.1340 val_ap=0.9461 val_f1@0.5=0.8786
# epoch=015 loss=0.1327 val_ap=0.9526 val_f1@0.5=0.8835
# epoch=016 loss=0.1318 val_ap=0.9412 val_f1@0.5=0.8737
# epoch=017 loss=0.1302 val_ap=0.9438 val_f1@0.5=0.8674
# epoch=018 loss=0.1279 val_ap=0.9486 val_f1@0.5=0.8739
# epoch=019 loss=0.1268 val_ap=0.9576 val_f1@0.5=0.8962
# epoch=020 loss=0.1268 val_ap=0.9549 val_f1@0.5=0.8930
# epoch=021 loss=0.1246 val_ap=0.9606 val_f1@0.5=0.8958
# epoch=022 loss=0.1248 val_ap=0.9657 val_f1@0.5=0.9043
# epoch=023 loss=0.1250 val_ap=0.9663 val_f1@0.5=0.9043
# epoch=024 loss=0.1240 val_ap=0.9676 val_f1@0.5=0.9036
# epoch=025 loss=0.1241 val_ap=0.9579 val_f1@0.5=0.9013
# epoch=026 loss=0.1229 val_ap=0.9609 val_f1@0.5=0.9011
# epoch=027 loss=0.1228 val_ap=0.9668 val_f1@0.5=0.9096
# epoch=028 loss=0.1233 val_ap=0.9659 val_f1@0.5=0.9101
# epoch=029 loss=0.1226 val_ap=0.9650 val_f1@0.5=0.9036
# epoch=030 loss=0.1227 val_ap=0.9647 val_f1@0.5=0.9066
# hard_epoch=01 loss=0.1268 val_ap=0.9585 hard_negatives=2799
# hard_epoch=02 loss=0.1271 val_ap=0.9529 hard_negatives=2799
# hard_epoch=03 loss=0.1249 val_ap=0.9649 hard_negatives=2799
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/torchscript_exporter/symbolic_opset9.py:4553: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with GRU can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   return _generic_rnn(
# {
#   "seed": 42,
#   "model": "MultiScaleTemporalGRU-from-scratch",
#   "pose_sha256": "a6b0154968adfe6565e92f0dfd71e12af196efba8c4b8e7a186de2478246e7d4",
#   "sequence_length": 32,
#   "feature_dim": 89,
#   "recommended_threshold": 0.5,
#   "training_strategy": {
#     "checkpoint_metric": "validation_average_precision",
#     "hard_negative_epochs": 3,
#     "hard_negative_fraction": 0.2,
#     "hard_negative_boost": 3.0,
#     "threshold_metric": "confirmed_source_f1",
#     "confirm_frames": 3,
#     "cooldown_seconds": 15.0
#   },
#   "test": {
#     "accuracy": 0.9827469553450608,
#     "balanced_accuracy": 0.9201235413719944,
#     "precision": 0.7730496453900709,
#     "recall": 0.8515625,
#     "f1": 0.8104089219330854,
#     "specificity": 0.9886845827439887,
#     "false_positive_rate": 0.011315417256011316,
#     "samples": 2956.0,
#     "positive_samples": 128.0,
#     "negative_samples": 2828.0
#   },
#   "test_aggregates": {
#     "source_level": {
#       "accuracy": 0.968013468013468,
#       "balanced_accuracy": 0.950945800254827,
#       "precision": 0.7794117647058824,
#       "recall": 0.9298245614035088,
#       "f1": 0.8479999999999999,
#       "specificity": 0.9720670391061452,
#       "false_positive_rate": 0.027932960893854747,
#       "samples": 594.0,
#       "positive_samples": 57.0,
#       "negative_samples": 537.0
#     },
#     "group_label_level": {
#       "accuracy": 0.9432989690721649,
#       "balanced_accuracy": 0.9392424242424242,
#       "precision": 0.8367346938775511,
#       "recall": 0.9318181818181818,
#       "f1": 0.8817204301075268,
#       "specificity": 0.9466666666666667,
#       "false_positive_rate": 0.05333333333333334,
#       "samples": 194.0,
#       "positive_samples": 44.0,
#       "negative_samples": 150.0
#     }
#   },
#   "operational_test": {
#     "accuracy": 0.968013468013468,
#     "balanced_accuracy": 0.937003009662601,
#     "precision": 0.803030303030303,
#     "recall": 0.8983050847457628,
#     "f1": 0.8480000000000001,
#     "specificity": 0.9757009345794393,
#     "false_positive_rate": 0.024299065420560748,
#     "samples": 594.0,
#     "positive_samples": 59.0,
#     "negative_samples": 535.0,
#     "false_alerts": 15.0,
#     "true_alerts": 52.0,
#     "alert_precision": 0.7761194029850746,
#     "labeled_event_recall": 0.8813559322033898,
#     "negative_monitoring_hours": 0.5977371454881786,
#     "false_alarms_per_hour": 25.094642541830545,
#     "confirm_frames": 3.0,
#     "cooldown_seconds": 15.0
#   },
#   "per_dataset": {
#     "CAUCAFall": {
#       "accuracy": 0.8958333333333334,
#       "balanced_accuracy": 0.7888888888888889,
#       "precision": 0.3333333333333333,
#       "recall": 0.6666666666666666,
#       "f1": 0.4444444444444444,
#       "specificity": 0.9111111111111111,
#       "false_positive_rate": 0.08888888888888889,
#       "samples": 48.0,
#       "positive_samples": 3.0,
#       "negative_samples": 45.0
#     },
#     "FallVision": {
#       "accuracy": 0.963963963963964,
#       "balanced_accuracy": 0.9235404896421846,
#       "precision": 0.9625,
#       "recall": 0.8555555555555555,
#       "f1": 0.9058823529411764,
#       "specificity": 0.9915254237288136,
#       "false_positive_rate": 0.00847457627118644,
#       "samples": 444.0,
#       "positive_samples": 90.0,
#       "negative_samples": 354.0
#     },
#     "MCFD": {
#       "accuracy": 0.9535714285714286,
#       "balanced_accuracy": 0.910210425633668,
#       "precision": 0.7837837837837838,
#       "recall": 0.8529411764705882,
#       "f1": 0.8169014084507041,
#       "specificity": 0.967479674796748,
#       "false_positive_rate": 0.032520325203252036,
#       "samples": 280.0,
#       "positive_samples": 34.0,
#       "negative_samples": 246.0
#     },
#     "UCF101": {
#       "accuracy": 0.9948717948717949,
#       "balanced_accuracy": 0.9948717948717949,
#       "precision": 0.0,
#       "recall": 0.0,
#       "f1": 0.0,
#       "specificity": 0.9948717948717949,
#       "false_positive_rate": 0.005128205128205128,
#       "samples": 2145.0,
#       "positive_samples": 0.0,
#       "negative_samples": 2145.0
#     },
#     "URFD": {
#       "accuracy": 0.8461538461538461,
#       "balanced_accuracy": 0.9210526315789473,
#       "precision": 0.14285714285714285,
#       "recall": 1.0,
#       "f1": 0.25,
#       "specificity": 0.8421052631578947,
#       "false_positive_rate": 0.15789473684210525,
#       "samples": 39.0,
#       "positive_samples": 1.0,
#       "negative_samples": 38.0
#     }
#   },
#   "per_dataset_aggregates": {
#     "CAUCAFall": {
#       "source_level": {
#         "accuracy": 0.8,
#         "balanced_accuracy": 0.875,
#         "precision": 0.5,
#         "recall": 1.0,
#         "f1": 0.6666666666666666,
#         "specificity": 0.75,
#         "false_positive_rate": 0.25,
#         "samples": 10.0,
#         "positive_samples": 2.0,
#         "negative_samples": 8.0
#       },
#       "group_label_level": {
#         "accuracy": 0.5,
#         "balanced_accuracy": 0.5,
#         "precision": 0.5,
#         "recall": 1.0,
#         "f1": 0.6666666666666666,
#         "specificity": 0.0,
#         "false_positive_rate": 1.0,
#         "samples": 2.0,
#         "positive_samples": 1.0,
#         "negative_samples": 1.0
#       }
#     },
#     "FallVision": {
#       "source_level": {
#         "accuracy": 0.9668508287292817,
#         "balanced_accuracy": 0.9518617021276596,
#         "precision": 0.925,
#         "recall": 0.925,
#         "f1": 0.925,
#         "specificity": 0.9787234042553191,
#         "false_positive_rate": 0.02127659574468085,
#         "samples": 181.0,
#         "positive_samples": 40.0,
#         "negative_samples": 141.0
#       },
#       "group_label_level": {
#         "accuracy": 0.9668508287292817,
#         "balanced_accuracy": 0.9518617021276596,
#         "precision": 0.925,
#         "recall": 0.925,
#         "f1": 0.925,
#         "specificity": 0.9787234042553191,
#         "false_positive_rate": 0.02127659574468085,
#         "samples": 181.0,
#         "positive_samples": 40.0,
#         "negative_samples": 141.0
#       }
#     },
#     "MCFD": {
#       "source_level": {
#         "accuracy": 0.8636363636363636,
#         "balanced_accuracy": 0.8392857142857143,
#         "precision": 0.8666666666666667,
#         "recall": 0.9285714285714286,
#         "f1": 0.896551724137931,
#         "specificity": 0.75,
#         "false_positive_rate": 0.25,
#         "samples": 22.0,
#         "positive_samples": 14.0,
#         "negative_samples": 8.0
#       },
#       "group_label_level": {
#         "accuracy": 0.6666666666666666,
#         "balanced_accuracy": 0.5,
#         "precision": 0.6666666666666666,
#         "recall": 1.0,
#         "f1": 0.8,
#         "specificity": 0.0,
#         "false_positive_rate": 1.0,
#         "samples": 3.0,
#         "positive_samples": 2.0,
#         "negative_samples": 1.0
#       }
#     },
#     "UCF101": {
#       "source_level": {
#         "accuracy": 0.9813829787234043,
#         "balanced_accuracy": 0.9813829787234043,
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1": 0.0,
#         "specificity": 0.9813829787234043,
#         "false_positive_rate": 0.018617021276595744,
#         "samples": 376.0,
#         "positive_samples": 0.0,
#         "negative_samples": 376.0
#       },
#       "group_label_level": {
#         "accuracy": 0.3333333333333333,
#         "balanced_accuracy": 0.3333333333333333,
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1": 0.0,
#         "specificity": 0.3333333333333333,
#         "false_positive_rate": 0.6666666666666666,
#         "samples": 3.0,
#         "positive_samples": 0.0,
#         "negative_samples": 3.0
#       }
#     },
#     "URFD": {
#       "source_level": {
#         "accuracy": 0.8,
#         "balanced_accuracy": 0.875,
#         "precision": 0.5,
#         "recall": 1.0,
#         "f1": 0.6666666666666666,
#         "specificity": 0.75,
#         "false_positive_rate": 0.25,
#         "samples": 5.0,
#         "positive_samples": 1.0,
#         "negative_samples": 4.0
#       },
#       "group_label_level": {
#         "accuracy": 0.8,
#         "balanced_accuracy": 0.875,
#         "precision": 0.5,
#         "recall": 1.0,
#         "f1": 0.6666666666666666,
#         "specificity": 0.75,
#         "false_positive_rate": 0.25,
#         "samples": 5.0,
#         "positive_samples": 1.0,
#         "negative_samples": 4.0
#       }
#     }
#   },
#   "cache_shards": [
#     "/kaggle/input/notebooks/quangnguynv/elder-fall-detection-no-02/eldercare_cache_fallvision/shard_manifest.csv",
#     "/kaggle/input/notebooks/quangnguynv/elder-fall-detection-no-03/eldercare_cache_caucafall/shard_manifest.csv",
#     "/kaggle/input/notebooks/quangnguynv/elder-fall-detection-no-04/eldercare_cache_urfd/shard_manifest.csv",
#     "/kaggle/input/notebooks/quangnguynv/elder-fall-detection-no-05/eldercare_cache_mcfd/shard_manifest.csv",
#     "/kaggle/input/notebooks/quangnguynv/elder-fall-detection-no-06/eldercare_cache_ucf101/shard_manifest.csv"
#   ]
# }
# Final classifier: /kaggle/working/eldercare_training/temporal_attention.pt
